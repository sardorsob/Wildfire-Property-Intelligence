# %% [markdown]
# # Dataset feature glossary
#
# This static table documents the dataset features; its literal values and LaTeX export schema are retained.

# %%
import pandas as pd
import numpy as np

# %%
data = {'Feature' : ['fips' , 'st_damcat' , 'bldgtype' , 'lc_type' , 'clr' , 'clr_cc'], 
        'Values' : ['Unique Identifier for each county in California (total of 58 counties)', 
        "['RES' 'COM' 'IND' 'PUB']",
        "['M' 'S' 'W' 'C' 'H']", 
        "['urban+crop' 'urban+forest' 'urban+grass' 'urban+shrub' 'crop' 'forest' 'shrub' 'grass' 'barren' 'urban+barren' 'urban' 'urban+other' 'other']",
        'Names of different colors (38 total)', 
        '[0, 377]'],
        'Data Type' : ['Unique ID', 'Categorical', 'Categorical', 'Categorical', 'Categorical', 'Numeric']}
df = pd.DataFrame.from_dict(data)
df
# Out:
#      Feature                                             Values    Data Type
# 0       fips  Unique Identifier for each county in Californi...    Unique ID
# 1  st_damcat                          ['RES' 'COM' 'IND' 'PUB']  Categorical
# 2   bldgtype                              ['M' 'S' 'W' 'C' 'H']  Categorical
# 3    lc_type  ['urban+crop' 'urban+forest' 'urban+grass' 'ur...  Categorical
# 4        clr               Names of different colors (38 total)  Categorical
# 5     clr_cc                                           [0, 377]      Numeric

# %%
with open("features_table.tex", 'w') as f:
    f.write(df.to_latex(index=False))
